# %%
import re
import pdfplumber

# %%
# Import our schedule Pdf function

class pdfExtractor:
    # Our mission here is to extract the necessary data from the table on the schedule pdf

    def __init__(self, schedulePath):
      self.schedulePath = schedulePath
    
    def showPath(self):
       print(f"Name: {self.schedulePath} ")

    def pdfToText(self):
       with pdfplumber.open(self.schedulePath) as pdf:
            all_text = ""
            for page in pdf.pages:
                all_text += page.extract_text() + "\n"
                print(all_text)

# %%
schedule1 = pdfExtractor("schedule.pdf")
schedule1.pdfToText()
# Out:
# VUE Admissions Manager Daily Schedule
# Saturday, May 11, 2024
# Time Candidate Client CCID Exam Notes
# 8 AM
# 8:00 AM Adegbite, Joseph ISC2 CC: Certified in
# 120 Min. Cybersecurity (CC)
# 8:00 AM Benjamin, Marissa Texas Departm... InsTX-Life01: Life
# Jaquena 120 Min. Agent (English)
# 8:00 AM Crowley, Tosha Texas Departm... InsTX-LAH05:
# 150 Min. General Lines - Life,
# Accident and Health
# (English)
# 8:00 AM Dukes, Malik Palo Alto Netw... PSE-Strata: Palo Alto
# Devaghn 90 Min. Networks System
# Engineer
# Professional - Strata
# 8:00 AM Ellis, Julian Texas Departm... InsTX-LAH05:
# 150 Min. General Lines - Life,
# Accident and Health
# (English)
# 8:00 AM Givings, Michele K Texas Departm... InsTX-LAH05:
# 150 Min. General Lines - Life,
# Accident and Health
# (English)
# 8:00 AM Graham, Evan TSA - USA Hire TSO: Transportation
# 120 Min. Security Officer
# 8:00 AM Jimenez, Faver Texas Departm... InsTX-LAH25:
# 150 Min. General Lines - Life,
# Accident and Health
# (Spanish)
# ...

# %%
class pdfFillerOuter:
    # Our mission here is to fill out the pearson vue agreements forms using the data extracted from the 
    
def pdfPrinterOuter:
    # Print them pdfs out.
